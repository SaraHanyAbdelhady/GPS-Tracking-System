# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraHanyAbdelhady/GPS-Tracking-System/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import pandas as pd
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px

# %%
trajectory = r'"C:\Users\hp\Documents\Map Plotting\trajectory.xlsx"'

# %%
df = pd.read_csv(tajectory)
# Out:
#        type version                               comment    name database  \
# 0    header   5.0.2  Export to JSON plugin for PHPMyAdmin     NaN      NaN
# 1  database     NaN                                   NaN    test      NaN
# 2     table     NaN                                   NaN  cities     test
#
#                                                 data
# 0                                                NaN
# 1                                                NaN
# 2  [{'id': '1', 'governorate_id': '1', 'city_name...

# %%
df

# %%
#using geopandas to convert long and lat to points
df_geo = gpd.GeoDataFrame(df, geometry = gpd.points_from_xy(df.longitude , df.latitude))

# %%
df_geo

# %%
#get built in dataset from geopandas
world_data = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#plot world map
axis = world_data[world_data.continent == 'Africa'].plot(color = 'lightblue' , edgecolor = 'black')
#df_geo.plot(ax = axis , color = 'black')
plt.title('WA Countries')
# Out:
# <ipython-input-30-bb2854c2626a>:2: FutureWarning:
#
# The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
# Text(0.5, 1.0, 'WA Countries')

# %%
#cities = pd.read_json("/content/cities.json")

# %%
import plotly.express as px
import pandas as pd
df = px.data.carshare()

# %%
df.head(10)
# Out:
#    centroid_lat  centroid_lon    car_hours  peak_hour
# 0     45.471549    -73.588684  1772.750000          2
# 1     45.543865    -73.562456   986.333333         23
# 2     45.487640    -73.642767   354.750000         20
# 3     45.522870    -73.595677   560.166667         23
# 4     45.453971    -73.738946  2836.666667         19
# 5     45.573126    -73.539902  1022.750000          1
# 6     45.530054    -73.628036   835.750000         18
# 7     45.499193    -73.561944  1888.333333         14
# 8     45.551301    -73.611712  1030.750000          2
# 9     45.553810    -73.577207  1841.166667          1

# %%
fig = px.scatter_mapbox(df, lon = df['centroid_lon'], lat = df['centroid_lat'])
fig.update_layout(mapbox_style = "open-street-map")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.DataFrame({'longitude': [31.278864340128457],
                   'latitude': [30.064813965618775]})
df.head()
# Out:
#    longitude   latitude
# 0  31.278864  30.064814

# %%
fig = px.scatter_mapbox(df, lon = df['longitude'], lat = df['latitude'])
fig.update_layout(mapbox_style = "open-street-map")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
